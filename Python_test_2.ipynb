# %%
n = int(input("Enter the number: "))

if n == 0:
    print("The number is zero")
else:
    if n % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
# Out:
# Enter the number: 01
# The number is odd

# %%
def reverse_string(s):
    reversed_s = ""
    for char in s:
        reversed_s = char + reversed_s
    return reversed_s

print(reverse_string("SEE YOU LATER"))
# Out:
# RETAL UOY EES

# %%
def find_largest(numbers):
    largest = numbers[0]
    for num in numbers:
        if num > largest:
            largest = num
    return largest

nums = list(map(int, input("Enter numbers separated by spaces: ").split()))

print("Largest number:", find_largest(nums))
# Out:
# Enter numbers separated by spaces: 4 88 9 6456 4554
# Largest number: 6456

# %%
def is_palindrome(s):
    s = s.lower()  #
    return s == s[::-1]

word = input("Enter a string: ")
if is_palindrome(word):
    print("It's a palindrome!")
else:
    print("Not a palindrome!")
# Out:
# Enter a string: DAD
# It's a palindrome!

# %%
def count_characters(s):
    char_count = {}
    for char in s:
        if char in char_count:
            char_count[char] += 1
        else:
            char_count[char] = 1
    return char_count
text = input("Enter a string: ")
char_counts = count_characters(text)

for char, count in char_counts.items():
    print(f"'{char}': {count}")
# Out:
# Enter a string: UDAYKIRANTHIGALA
# 'U': 1
# 'D': 1
# 'A': 4
# 'Y': 1
# 'K': 1
# 'I': 2
# 'R': 1
# 'N': 1
# 'T': 1
# 'H': 1
# 'G': 1
# 'L': 1

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

    def show(self):
        print("Car brand:", self.brand)

a = Car("Mahindra")
a.show()
# Out:
# Car brand: Mahindra

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")
class Dog(Animal):
    def speak(self):
        print("Dog barks")

a = Animal()
a.speak()

b = Dog()
b.speak()
# Out:
# Animal makes a sound
# Dog barks

# %%
class Vehicle:
    def fuel_type(self):
        print("Most vehicles use petrol or diesel")

class ElectricCar(Vehicle):
    def fuel_type(self):
        print("Electric cars use battery power")

a = Vehicle()
a.fuel_type()

b = ElectricCar()
b.fuel_type()
# Out:
# Most vehicles use petrol or diesel
# Electric cars use battery power

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        print(f"New Balance: {self.__balance}")

    def get_balance(self):
        return self.__balance

account = BankAccount(123456789)
account.deposit(8250)
print(account.get_balance())
# Out:
# New Balance: 123465039
# 123465039
